# %% [markdown]
# # **Introduction**
#
# Entanglement is a key feature of quantum computing, and it plays a critical role in many quantum algorithms. In this tutorial, we will explore how to create and manipulate entangled states using Qiskit, a popular open-source quantum computing framework developed by IBM.
#
# Before we begin, it's worth briefly defining what we mean by entanglement. In quantum mechanics, entanglement refers to a state where the properties of two or more particles are correlated in such a way that their joint state cannot be described by the states of the individual particles. This means that measuring the state of one particle instantly affects the state of the other particle, no matter how far apart they are. This effect is sometimes referred to as "spooky action at a distance" and is one of the key features of quantum mechanics.

# %% [markdown]
# First let us install qiskit...

# %%
# !pip install qiskit[visualization]
# !pip install qiskit_aer
# Out:
# Requirement already satisfied: qiskit[visualization] in /home/timofey/envTF/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /usr/lib/python3/dist-packages (from qiskit[visualization]) (1.11.4)
# Requirement already satisfied: dill>=0.3 in /usr/lib/python3/dist-packages (from qiskit[visualization]) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (5.7.0)
# Requirement already satisfied: typing-extensions in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (4.14.1)
# Requirement already satisfied: matplotlib>=3.3 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (3.8.4)
# Requirement already satisfied: pydot in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (4.0.1)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/lib/python3/dist-packages (from qiskit[visualization]) (10.2.0)
# Requirement already satisfied: pylatexenc>=1.4 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /usr/lib/python3/dist-packages (from qiskit[visualization]) (1.12)
# Requirement already satisfied: contourpy>=1.0.1 in /home/timofey/envTF/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/timofey/envTF/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/timofey/envTF/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/timofey/envTF/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/timofey/envTF/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/timofey/envTF/lib/python3.12/site-packages (from matplotlib>=3.3->qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/timofey/envTF/lib/python3.12/site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.3.1)
# Requirement already satisfied: pytz>=2020.1 in /home/timofey/envTF/lib/python3.12/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/timofey/envTF/lib/python3.12/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: qiskit_aer in /home/timofey/envTF/lib/python3.12/site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit_aer) (2.3.1)
# Requirement already satisfied: numpy>=1.16.3 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /usr/lib/python3/dist-packages (from qiskit_aer) (1.11.4)
# Requirement already satisfied: psutil>=5 in /usr/lib/python3/dist-packages (from qiskit_aer) (5.9.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.0->qiskit_aer) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/lib/python3/dist-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit_aer) (5.7.0)
# Requirement already satisfied: typing-extensions in /home/timofey/envTF/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit_aer) (4.14.1)

# %%
import sys
sys.path = [p for p in sys.path if 'dist-packages' not in p]

# %% [markdown]
# ...and import relevant libraries for math, to create quantum circuits and visualizing ket vectors.

# %%
import qiskit
print(qiskit.__version__)

import numpy as np
import math
from math import pi
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector, DensityMatrix
from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_city, plot_distribution
from qiskit.primitives import StatevectorSampler, StatevectorEstimator
from qiskit_aer import Aer
from qiskit.circuit.library import UnitaryGate
from qiskit.quantum_info import DensityMatrix
from mpl_toolkits.mplot3d import Axes3D
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import qiskit
#       2 print(qiskit.__version__)
#       4 import numpy as np
#
# File ~/envTF/lib/python3.12/site-packages/qiskit/__init__.py:147
#     144 from qiskit.exceptions import QiskitError, MissingOptionalLibraryError
#     146 # The main qiskit operators
# --> 147 from qiskit.circuit import ClassicalRegister
#     148 from qiskit.circuit import QuantumRegister
#     149 from qiskit.circuit import AncillaRegister
#
# File ~/envTF/lib/python3.12/site-packages/qiskit/circuit/__init__.py:1412
#    1410 from .quantumcircuitdata import CircuitInstruction
#    1411 from .equivalence import EquivalenceLibrary
# -> 1412 from . import library
#    1413 from .equivalence_library import StandardEquivalenceLibrary, SessionEquivalenceLibrary
#    1414 from .commutation_checker import CommutationChecker
#
# File ~/envTF/lib/python3.12/site-packages/qiskit/circuit/library/__init__.py:908
#     882 from .blueprintcircuit import BlueprintCircuit
#     883 from .generalized_gates import (
#     884     Diagonal,
#     885     DiagonalGate,
#    (...)
#     906     UCRZGate,
#     907 )
# --> 908 from .pauli_evolution import PauliEvolutionGate
#     909 from .pauli_product_measurement import PauliProductMeasurement
#     910 from .hamiltonian_gate import HamiltonianGate
#
# File ~/envTF/lib/python3.12/site-packages/qiskit/circuit/library/pauli_evolution.py:19
#      17 from typing import TYPE_CHECKING
#      18 import numpy as np
# ---> 19 import scipy as sc
#      21 from qiskit.circuit.gate import Gate
#      22 from qiskit.circuit.quantumcircuit import ParameterValueType
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# ## Bell states and the density matrix
#
# The density matrix is a way of representing the state of a quantum system, and it's a useful tool for understanding entangled states. In Qiskit, we can obtain the density matrix of a quantum state using the DensityMatrix() function.
#
# **Exercise 1:** Create a two qubit quantum circuit, use elementary gates to create the state $|\Phi^+\rangle$ and visualize the density matrix of the state by plotting the real and imaginary parts of the density matrix. Initialize the circuit differently to generate the states $|\Phi^-\rangle$, $|\Psi^+\rangle$ and $|\Psi^-\rangle$ (consider that Qiskit inverts the order of bits). Use the plot_state_city function to represent the density matrix.

# %%
# Create a quantum circuit with two qubits and initialize it
from qiskit.visualization import plot_state_hinton


qc = QuantumCircuit(2)
qc.initialize(0)
# Function to create a Bell state
qc.h(0)
qc.cx(0,1)

# Function to display the density matrix
dm = DensityMatrix(qc)
plot_state_hinton(dm, title='Phi+')
# change the basis to the Bell states


# print the circuit


# display the density matrix of the state

# %%
qc.z(0)
dm = DensityMatrix(qc)
plot_state_hinton(dm, title='Phi-')

# %%
qc = QuantumCircuit(2)
qc.initialize(0)
# Function to create a Bell state
qc.h(0)
qc.cx(0,1)
qc.x(1)
dm = DensityMatrix(qc)
plot_state_hinton(dm, title='Psi+')

# %%
qc = QuantumCircuit(2)
qc.initialize(0)
# Function to create a Bell state
qc.h(0)
qc.cx(0,1)
qc.x(1)
qc.z(0)
dm = DensityMatrix(qc)
plot_state_hinton(dm, title='Psi-')

# %% [markdown]
# **Exercise 2:** do the same as before by using the mixed states corresponding to the Bell states. Comment on the differences in the density matrices.

# %%
# Build the desity matrices
dm_00 = DensityMatrix.from_label('00')
dm_11 = DensityMatrix.from_label('11')
dm_01 = DensityMatrix.from_label('01')
dm_10 = DensityMatrix.from_label('10')

# display the density matrix

dm_mixed_phi0 = 0.5*dm_00 + 0.5*dm_11
plot_state_hinton(dm_mixed_phi0)

# %%
dm_mixed_phi1 = 0.5*dm_00 - 0.5*dm_11
plot_state_hinton(dm_mixed_phi1)

# %%
dm_mixed_psi0 = 0.5*dm_01 + 0.5*dm_10
plot_state_hinton(dm_mixed_psi0)

# %%
dm_mixed_psi1 = 0.5*dm_01 - 0.5*dm_10
plot_state_hinton(dm_mixed_psi1)

# %% [markdown]
# **Exercise 3:** Add measurements to the circuit. Use the statevector simulator (linear algebra of the states and the unitaries) to simulate the output of the circuit. Perform measurements on the computational basis and on the $|+\rangle$ and $|-\rangle$ basis. Try this for all Bell states.

# %%
# Create a quantum circuit with two qubits and initialize it


# change the basis to the Bell states


# add the Hadamards to change basis to |+>,|->


# add the measurement


# Simulate the circuit using the statevector simulator


# print the circuit and plot the hystograms of results

# %% [markdown]
# **Exercise 4:** Rewrite by hand the Bell states on the $|+\rangle$ and $|-\rangle$ basis. Comment the previous results in the light of what you have found. **Hint:** Remember that $|0\rangle=\frac{1}{\sqrt{2}}\left(|+\rangle+|-\rangle\right)$ and $|1\rangle=\frac{1}{\sqrt{2}}\left(|+\rangle-|-\rangle\right)$.

# %% [markdown]
# **Exercise 5:** Build a quantum circuit to generate the Greenberger–Horne–Zeilinger state $|GHZ\rangle=\frac{1}{\sqrt{2}}\left(|000\rangle+|111\rangle\right)$ and represent its density matrix.

# %% [markdown]
# **Exercise 6:** Do the same for the W state $|W\rangle=\frac{1}{\sqrt{3}}\left(|001\rangle+|010\rangle+|100⟩\right)$ using the circuit in the figure. The angle of the y rotation isc$\phi_3 = 2\arccos\left(\frac{1}{\sqrt{3}}\right)$. To implement the controlled Hadamard gate use the to_gate method of a quantum circuit adding one control.![picture](https://upload.wikimedia.org/wikipedia/commons/3/34/Wstate_quantumcircuit.png)
